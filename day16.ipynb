# %% [markdown]
# ### Day 16

# %%
import numpy as np
from math import prod
from collections import defaultdict, Counter

# %%
day_i = 16

# %%
# %run start_day.py $day_i
# Out:
# Initializing day 16

# %%
cd /home/vincent/Documents/AdventOfCode/2021
# Out:
# /home/vincent/Documents/AdventOfCode/2021

# %%
PATH = f"day{day_i}/input{day_i}"

# %%
# !wc -l $PATH
# Out:
# 1 day16/input16

# %%
# !head $PATH
# Out:
# ...

# %%
# !tail $PATH

# %%
str

# %%
str(bin(int("0", 16)))[2:].ljust(4, '0')
# Out:
# '0000'

# %%
def parse_input(inp):
    s = ""
    for c in inp[0]:
        s += str(bin(int(c, 16)))[2:].rjust(4, '0')
    return s

# %%
# real input
with open(PATH, 'r') as f:
    inputs = parse_input([x.strip() for x in f.readlines()])

# %%
# test input
test_str1 = ["38006F45291200"]
test_str2 = ["EE00D40C823060"]

test_str3 = ["8A004A801A8002F478"]
test_str4 = ["620080001611562C8802118E34"]
test_str5 = ["C0015000016115A2E0802F182340"]
test_str6 = ["A0016C880162017C3686B18A3D4780"]


inputs_1 = parse_input(test_str1)
inputs_2 = parse_input(test_str2)
inputs_3 = parse_input(test_str3)
inputs_4 = parse_input(test_str4)
inputs_5 = parse_input(test_str5)
inputs_6 = parse_input(test_str6)

# %%
inputs_1
# Out:
# '00111000000000000110111101000101001010010001001000000000'

# %%
def read_literal(p):
    i = 6
    group = p[i:i+5]
    binary = ""
    while group[0] == '1':
        binary += group[1:]
        i += 5
        group = p[i:i+5]
    binary += group[1:]
#     end = (i + 4 + 3 - (i % 4))
    end = i + 5
    return int(binary, 2), end


class Packet():
    OPERATIONS = [sum, prod, min, max]
    
    def __init__(self, p, debug=False):
        if len(p) > 6: self.version, self.ID = int(p[:3], 2), int(p[3:6], 2)
        else: self.version, self.ID = None, None
        self.value = None
        self.subpackets = []
        self.debug = debug
        
        if self.debug: 
            print(f"PARSING {p if len(p) < 40 else (p[:38] + '...')}")
            if len(p) > 6:
                print(f"        VVVTTT{'AAAAA' if self.ID == 4 else ('I' + 'L' * (15 if p[6] == '0' else 11))}")
            print(f"\tversion {self.version}\n\tID {self.ID}")
        self.parse_content(p, self.ID)
    
    def parse_content(self, content, ID):
        if ID == 4:
            self.value, self.end_position = read_literal(content)
            if self.debug: print(f'\tvalue - {self.value}\n\tend - {self.end_position}')
        elif content == '' or int(content, 2) == 0 or self.version is None:
            self.end_position = len(content) - 1
        else:
            length_type_ID = content[6]
            assert len(content) > 6, f"Cannot find length_type_ID in {content}"
            if self.debug: print(f"\tlength type {length_type_ID}")
            if length_type_ID == '1':
                assert len(content) > 18, f"Content too short for length_type_ID 1 - {content}"
                number_of_subpackets = int(content[7:18], 2)
                if self.debug: print(f"\tnumber of subpackets {number_of_subpackets}")
                start = 18
                for i in range(number_of_subpackets):
                    subpacket = Packet(content[start:], self.debug)
                    if subpacket.end_position == 0:
                        break
                    self.subpackets.append(subpacket)
                    start += subpacket.end_position
                self.end_position = start
            else:
                assert len(content) > 22, f"Content too short for length_type_ID 1 - {content}"
                total_length_in_bits = int(content[7:22], 2)
                if self.debug: print(f"\tnumber of bits {total_length_in_bits}")
                self.end_position = 22 + total_length_in_bits
                start = 22
                while start < self.end_position:
                    subpacket = Packet(content[start:self.end_position], self.debug)
                    if subpacket.end_position == 0:
                        break
                    self.subpackets.append(subpacket)
                    start += subpacket.end_position
    
    def sum_of_versions(self):
        return self.version + sum([p.sum_of_versions() for p in self.subpackets])
    
    def to_string(self, offset = ""):
        if self.value is None:
            return offset + f'ID {self.ID}:\n' + '\n'.join([sub.to_string(offset + '\t') for sub in self.subpackets])
        else:
            return offset + f'value = {self.value}'
        
    def evaluate(self):
        if self.value is not None:
            return self.value
        elif self.ID < 4:
            return self.OPERATIONS[self.ID](x.evaluate() for x in self.subpackets)
        elif self.ID == 5:
            values = [x.evaluate() for x in self.subpackets]
            return int(values[0] > values[1])
        elif self.ID == 6:
            values = [x.evaluate() for x in self.subpackets]
            return int(values[0] < values[1])
        elif self.ID == 7:
            values = [x.evaluate() for x in self.subpackets]
            return int(values[0] == values[1])
        


def solve1(inp, debug=False):
    p = Packet(inp, debug)
    return p.sum_of_versions()

def solve2(inp, debug=False):
    p = Packet(inp, debug)
    return p.evaluate()

# %%
inputs_1
# Out:
# '00111000000000000110111101000101001010010001001000000000'

# %%
inputs_1[22:]
# Out:
# '1101000101001010010001001000000000'

# %% [raw]
# 00111000000000000110111101000101001010010001001000000000
#                   10111101000101001010010001001000000000
#                                     10010001001000000000

# %% [raw]
# A                     1101000101001010010001001000000000
# B                                01010010001001000000000

# %%
Packet(inputs_1, debug=True)
# Out:
# PARSING 00111000000000000110111101000101001010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 6
# 	length type 0
# 	number of bits 27
# PARSING 110100010100101001000100100
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 0101001000100100
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 20
# 	end - 16

# %%
print(Packet(inputs_1).to_string())
# Out:
# ID 6:
# 	value = 10
# 	value = 20

# %% [raw]
# 11101110000000001101010000001100100000100011000001100000
# VVVTTTILLLLLLLLLLLAAAAAAAAAAABBBBBBBBBBBCCCCCCCCCCC

# %%
Packet(inputs_2, debug=True)
# Out:
# PARSING 11101110000000001101010000001100100000...
#         VVVTTTILLLLLLLLLLL
# 	version 7
# 	ID 3
# 	length type 1
# 	number of subpackets 3
# PARSING 01010000001100100000100011000001100000
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 1
# 	end - 11
# PARSING 100100000100011000001100000
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 2
# 	end - 11
# PARSING 0011000001100000
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 3
# 	end - 11

# %%
print(Packet(inputs_2).to_string())
# Out:
# ID 3:
# 	value = 1
# 	value = 2
# 	value = 3

# %%
print(solve1(inputs_3))
# Out:
# 16

# %%
print(solve1(inputs_4))
# Out:
# 12

# %% [raw]
# 1100000000000001010100000000000000000001011000010001010110100010111000001000000000101111000110000010001101000000
# VVVIIILXXXXXXXXXXXXXXX000000000000000001011000010001010110100010111000001000000000101111000110000010001101000000
#                       000000000000000001011000010001010110100010111000001000000000101111000110000010001101000000
#                       VVVIIILXXXXXXXXXXXXXXX00010001010110100010111000001000000000101111000110000010001101000000
#                                             00010001010110100010111000001000000000101111000110000010001101000000
#                                             VVVIII01010
#                                                        110100010111000001000000000101111000110000010001101000000
#                                                        VVVIII01011
#                                                                   1000001000000000101111000110000010001101000000
#                                                                   VVVIIILXXXXXXXXXXX
#                                                                                     1111000110000010001101000000
#                                                                                     VVVIII01100
#                                                                                                00010001101000000
#                                                                                                VVVIII01101

# %%
print(solve1(inputs_5, debug=True))
# Out:
# PARSING 11000000000000010101000000000000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 0
# 	number of bits 84
# PARSING 00000000000000000101100001000101011010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 0
# 	length type 0
# 	number of bits 22
# PARSING 0001000101011010001011
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 11010001011
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 10000010000000001011110001100000100011...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 0
# 	length type 1
# 	number of subpackets 2
# PARSING 1111000110000010001101
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 12
# 	end - 11
# PARSING 00010001101
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 13
# 	end - 11
# 23

# %%
print(Packet(inputs_5).to_string())
# Out:
# ID 0:
# 	ID 0:
# 		value = 10
# 		value = 11
# 	ID 0:
# 		value = 12
# 		value = 13

# %%
print(Packet(inputs_6).to_string())
# Out:
# ID 0:
# 	ID 0:
# 		ID 0:
# 			value = 6
# 			value = 6
# 			value = 12
# 			value = 15
# 			value = 15

# %%
print(solve1(inputs_6))
# Out:
# 31

# %%
int('00111100', 2)
# Out:
# 60

# %%
Packet(inputs, True)
# Out:
# PARSING 00000010000011010111100100000000010100...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 0
# 	length type 1
# 	number of subpackets 53
# PARSING 11100100000000010100001101001001101100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 1
# 	length type 0
# 	number of bits 80
# PARSING 11010010011011000001001111101100000100...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 60
# 	end - 16
# PARSING 00010011111011000001001101001000001100...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 252
# 	end - 16
# PARSING 00010011010010000011001001101101001100...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 168
# 	end - 16
# PARSING 00110010011011010011001101101010
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 61
# 	end - 16
# PARSING 0011001101101010
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 186
# 	end - 16
# PARSING 11001110000000001110110000101001100111...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 3
# 	length type 1
# 	number of subpackets 3
# PARSING 10110000101001100111100110101010001011...
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 5
# 	end - 11
# PARSING 00110011110011010101000101110010010100...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 237
# 	end - 16
# PARSING 01010001011100100101001111011010101100...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 10010010100111101101010110011100100010...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 322158
# 	end - 31
# PARSING 01000100000000101000000101110000000001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 0
# 	number of bits 160
# PARSING 01011100000000010100101001001101011100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 7
# 	length type 0
# 	number of bits 82
# PARSING 10010011010111001011010011111011000101...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 180763931
# 	end - 41
# PARSING 11110011010111001011010011111011000101...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 180763931
# 	end - 41
# PARSING 01110010011101001100011000100011111011...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 225622007682
# 	end - 56
# PARSING 01100110000000001000111000000000011011...
#         VVVTTTILLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 00111000000000011011101010000000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 6
# 	length type 0
# 	number of bits 110
# PARSING 10100000000000001000011111000101101010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 111100010110101000010000110001111
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 0101000010000110001111
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 4
# 	end - 11
# PARSING 00110001111
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 15
# 	end - 11
# PARSING 10100000000000001000011001000101001110...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 100100010100111000111010010000010
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 0111000111010010000010
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 14
# 	end - 11
# PARSING 10010000010
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 2
# 	end - 11
# PARSING 11010001110011100101011110111011100111...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 14
# 	end - 11
# PARSING 01110010101111011101110011100001101110...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 402435806556
# 	end - 56
# PARSING 00000110000000001011111100000000011011...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 11111100000000011011101000000000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 7
# 	length type 0
# 	number of bits 110
# PARSING 10000000000000001000010001000110000110...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 4
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 000100011000011000010111110000011
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 12
# 	end - 11
# PARSING 0011000010111110000011
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 5
# 	end - 11
# PARSING 11110000011
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 11100000000000001000011101000111111010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 110100011111101000111010010001010
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 15
# 	end - 11
# PARSING 1101000111010010001010
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 14
# 	end - 11
# PARSING 10010001010
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 01010011110011110110011000000000100011...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 239
# 	end - 16
# PARSING 01100110000000001000110100000000010010...
#         VVVTTTILLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 00110100000000010010000001001001110010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 5
# 	length type 0
# 	number of bits 72
# PARSING 00010010011100101101011100110011000010...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 850169868
# 	end - 46
# PARSING 11010011101101101100001110
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 54926
# 	end - 26
# PARSING 11010011000001001110001000000000110101...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 132
# 	end - 16
# PARSING 11100010000000001101010011101001010011...
#         VVVTTTILLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 01010011101001010011001111011000010010...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 213
# 	end - 16
# PARSING 00110011110110000100101010010010011011...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 3721
# 	end - 21
# PARSING 01010010010011011010000000000001101101...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 45
# 	end - 16
# PARSING 10100000000000011011011001001100010100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 0
# 	length type 0
# 	number of bits 109
# PARSING 10010011000101001111100111100100100101...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 34039
# 	end - 26
# PARSING 10010010010100101001111001010100101001...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 140186
# 	end - 31
# PARSING 01010011000110001101110000111110111101...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 8958207
# 	end - 36
# PARSING 0111001100100100
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 148
# 	end - 16
# PARSING 00000110000000001010010110000000001010...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 10010110000000001010110011010101001010...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 5
# 	length type 1
# 	number of subpackets 2
# PARSING 10110011010101001010011100101010011010...
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 10767446
# 	end - 36
# PARSING 10010011110110001010101100110100101011...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 59484
# 	end - 26
# PARSING 11010010101101011111100100101000100000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 22004
# 	end - 26
# PARSING 10100010000000001011110000110100100110...
#         VVVTTTILLLLLLLLLLL
# 	version 5
# 	ID 0
# 	length type 1
# 	number of subpackets 2
# PARSING 11110000110100100110011001011100101001...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 6
# 	end - 11
# PARSING 10010011001100101110010100111110101101...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 9618683
# 	end - 36
# PARSING 01100110000000001001110010001100111100...
#         VVVTTTILLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 01110010001100111100111100010100011100...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 80330
# 	end - 31
# PARSING 00111000000000001101001111001111011101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 6
# 	length type 0
# 	number of bits 52
# PARSING 11110011110111011110010100101010001111...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 15582291
# 	end - 36
# PARSING 1111001001001110
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 46
# 	end - 16
# PARSING 00001010000000010001110011000001010111...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 2
# 	length type 1
# 	number of subpackets 4
# PARSING 01110011000001010111001110010100101011...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 133
# 	end - 16
# PARSING 01110011100101001010111111110001010100...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 205912145
# 	end - 41
# PARSING 00110011011101000100011110011011101001...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 2888
# 	end - 21
# PARSING 11110011011101001101111010000010000100...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 740257
# 	end - 31
# PARSING 00001000000000011100010101001011111011...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 2
# 	length type 0
# 	number of bits 113
# PARSING 01010010111110111001010010111111110010...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 2065890333
# 	end - 46
# PARSING 10010011111100101111111100000101101001...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 995266
# 	end - 31
# PARSING 110100101101111110100111001101001011
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 7294123
# 	end - 36
# PARSING 11000110000000001101010011100011101111...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 1
# 	length type 1
# 	number of subpackets 3
# PARSING 01010011100011101111001000100111001100...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 206
# 	end - 16
# PARSING 11110010001001110011001011101010111100...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 23
# 	end - 16
# PARSING 00110010111010101111001011111000101011...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 122
# 	end - 16
# PARSING 11110010111110001010110111011111010010...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 492927
# 	end - 31
# PARSING 10100100000000001000001001001011001100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 1
# 	length type 0
# 	number of bits 32
# PARSING 10010010110011001001001000100110
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 108
# 	end - 16
# PARSING 1001001000100110
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 22
# 	end - 16
# PARSING 10100110000000001001110001100011110000...
#         VVVTTTILLLLLLLLLLL
# 	version 5
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 01110001100011110000000000100100000110...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 12
# 	end - 11
# PARSING 01111000000000010010000011001100011001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 6
# 	length type 0
# 	number of bits 72
# PARSING 00110011000110011111101001110100110101...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 35321
# 	end - 26
# PARSING 11010011010100011100010110101011010011...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 2709935303
# 	end - 46
# PARSING 01010011001001100000011000000000101001...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 150
# 	end - 16
# PARSING 00000110000000001010011000000000001000...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 10011000000000001000000011001101101110...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 4
# 	ID 6
# 	length type 0
# 	number of bits 32
# PARSING 00110011011011100001001110000000
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 190
# 	end - 16
# PARSING 0001001110000000
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 192
# 	end - 16
# PARSING 11010011000101011101100111110001100000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 34231
# 	end - 26
# PARSING 11000110000000010010010011110011101111...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 1
# 	length type 1
# 	number of subpackets 4
# PARSING 10010011110011101111001001100001001100...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 238
# 	end - 16
# PARSING 11110010011000010011001101000111100100...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 49
# 	end - 16
# PARSING 00110011010001111001000111100100100000...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 167
# 	end - 16
# PARSING 10010001111001001000000001001000110010...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 15
# 	end - 11
# PARSING 00100100000000100100011001011000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 1
# 	length type 0
# 	number of bits 145
# PARSING 10010110000000001011000010000000001100...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 5
# 	length type 1
# 	number of subpackets 2
# PARSING 11000010000000001100110001011010100010...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 00110001011010100010100001000100110100...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 01010001010000100010011010000000000000...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 00010001001101000000000000010000111110...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 9
# 	end - 11
# PARSING 10100000000000001000011111000001000010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 111100000100001000010011110001001
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 2
# 	end - 11
# PARSING 0001000010011110001001
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 4
# 	end - 11
# PARSING 11110001001
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 9
# 	end - 11
# PARSING 010100111001001000111
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 3111
# 	end - 21
# PARSING 01010010101111101111111010101001110001...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 99591370
# 	end - 41
# PARSING 00101010000000001010110011001110101100...
#         VVVTTTILLLLLLLLLLL
# 	version 1
# 	ID 2
# 	length type 1
# 	number of subpackets 2
# PARSING 10110011001110101100110111111100110111...
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 10131437
# 	end - 36
# PARSING 11110011011000101000010000000001000010...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 178
# 	end - 16
# PARSING 10000100000000010000101111001000100001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 4
# 	ID 1
# 	length type 0
# 	number of bits 66
# PARSING 11110010001000011001101000000000101001...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 17
# 	end - 16
# PARSING 10011010000000001010010010110110110001...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 6
# 	length type 1
# 	number of subpackets 2
# PARSING 10010010110110110001101010000111
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 1715
# 	end - 21
# PARSING 01010000111
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 7
# 	end - 11
# PARSING 01000110000000000111010010010011100100...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 1
# 	number of subpackets 1
# PARSING 11010010010011100100010000000001101110...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 46
# 	end - 16
# PARSING 01000100000000011011100111001001110111...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 0
# 	number of bits 110
# PARSING 01110010011101111010011000001110111010...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 226439
# 	end - 31
# PARSING 01110100000000001110010101001011110111...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 5
# 	length type 0
# 	number of bits 57
# PARSING 01010010111101110000010110011011110011...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 1904
# 	end - 21
# PARSING 101100110111100111101100111010101000
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 12178264
# 	end - 36
# PARSING 10000110000000001010110100000000001000...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 10110100000000001000000111001011101101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 5
# 	length type 0
# 	number of bits 32
# PARSING 01110010111011010011001011101101
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 125
# 	end - 16
# PARSING 0011001011101101
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 125
# 	end - 16
# PARSING 00110010111100101011110100000110000110...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 468803
# 	end - 31
# PARSING 00001100000000101110010011001011110011...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 3
# 	length type 0
# 	number of bits 185
# PARSING 00110010111100111001110010111011111100...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 120794611
# 	end - 41
# PARSING 01010011000100001100011001000100011001...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 526482
# 	end - 31
# PARSING 00110010011101111100101111001100110101...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 14239
# 	end - 26
# PARSING 00110011010100011111110011101111001011...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 2717086384
# 	end - 46
# PARSING 11110010101101101101110111100111110101...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 90928092
# 	end - 41
# PARSING 11010000001010010100000000001111100101...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 1
# 	end - 11
# PARSING 01001010000000000111110010101110101010...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 2
# 	length type 1
# 	number of subpackets 1
# PARSING 11110010101110101010110011011010111001...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 369981
# 	end - 31
# PARSING 01110011111110101001010101000000110010...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 1024592
# 	end - 31
# PARSING 01100100000000011100111001001101111111...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 115
# PARSING 10010011011111111110000111010111000000...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 49095
# 	end - 26
# PARSING 01011100000000010000111001001000110100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 7
# 	length type 0
# 	number of bits 67
# PARSING 10010010001101001101101110110100111101...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 5310
# 	end - 26
# PARSING 11010011110111001101110100110111000000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 248204038
# 	end - 41
# PARSING 01100100000000100110011110001000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 153
# PARSING 11100010000000001101010000011010100011...
#         VVVTTTILLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 01010000011010100011110111000101001000...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 01010001111011100010100100001000000000...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 15
# 	end - 11
# PARSING 01110001010010000100000000011110100010...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 01000010000000001111010001000101100001...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 11010001000101100001100101000101110000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 8
# 	end - 11
# PARSING 10110000110010100010111000001000000000...
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 6
# 	end - 11
# PARSING 01010001011100000100000000011111100000...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 10000010000000001111110000010010100010...
#         VVVTTTILLLLLLLLLLL
# 	version 4
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 111100000100101000101100110001011
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 2
# 	end - 11
# PARSING 0101000101100110001011
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 00110001011
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 01000100000000100100001001010000000001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 0
# 	number of bits 144
# PARSING 10010100000000011010101110001000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 4
# 	ID 5
# 	length type 0
# 	number of bits 106
# PARSING 11100010000000001100110001001100100001...
#         VVVTTTILLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 00110001001100100001011111000110100000...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 9
# 	end - 11
# PARSING 10010000101111100011010000000000000000...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 5
# 	end - 11
# PARSING 11110001101000000000000000010000110010...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 13
# 	end - 11
# PARSING 00000000000000001000011001000001101010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 100100000110101000011111110000111
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 0101000011111110000111
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 7
# 	end - 11
# PARSING 11110000111
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 7
# 	end - 11
# PARSING 0001001100001000
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 136
# 	end - 16
# PARSING 11010001010000001100000000010000111000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 10
# 	end - 11
# PARSING 00000110000000001000011100000000001101...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 1
# 	length type 1
# 	number of subpackets 2
# PARSING 00011100000000001101001111001111110110...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 7
# 	length type 0
# 	number of bits 52
# PARSING 11110011111101101110100010111100101101...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 63186
# 	end - 26
# PARSING 11110010110101011111100100
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 26100
# 	end - 26
# PARSING 00010010101011000000000000000010100101...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 92
# 	end - 16
# PARSING 00000000000000101001011100010000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 0
# 	length type 0
# 	number of bits 165
# PARSING 11000100000000001000011111000001111010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 6
# 	ID 1
# 	length type 0
# 	number of bits 33
# PARSING 111100000111101000010101010001011
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 1101000010101010001011
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 5
# 	end - 11
# PARSING 01010001011
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 01100100000000001000011001000010010110...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 33
# PARSING 100100001001011000111001010001000
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 4
# 	end - 11
# PARSING 1011000111001010001000
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 14
# 	end - 11
# PARSING 01010001000
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 8
# 	end - 11
# PARSING 01000100000000001000010111000010110010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 0
# 	number of bits 33
# PARSING 011100001011001000100001010000011
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 5
# 	end - 11
# PARSING 1001000100001010000011
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 8
# 	end - 11
# PARSING 01010000011
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 11010011101100111000011101111111100000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 221306755
# 	end - 41
# PARSING 01001110000000010001010011010111001100...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 3
# 	length type 1
# 	number of subpackets 4
# PARSING 01010011010111001100011110100001011100...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 180936819
# 	end - 41
# PARSING 01110001101111100000100101001010010100...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 13
# 	end - 11
# PARSING 11110000010010100101001010000000011001...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 2
# 	end - 11
# PARSING 01010010100101000000001100100000001100...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 1088
# 	end - 21
# PARSING 01100100000001100110000010111000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 408
# PARSING 00101110000000000111000010000000000101...
#         VVVTTTILLLLLLLLLLL
# 	version 1
# 	ID 3
# 	length type 1
# 	number of subpackets 1
# PARSING 11000010000000000101100100000001010111...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 1
# 	number of subpackets 1
# PARSING 01100100000001010111101010110000000101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 350
# PARSING 10101100000001010010000100001000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 3
# 	length type 0
# 	number of bits 328
# PARSING 01000010000000000101000100000001001000...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 0
# 	length type 1
# 	number of subpackets 1
# PARSING 01000100000001001000000000100000000100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 1
# 	length type 0
# 	number of bits 288
# PARSING 00001000000001000010100100100000000011...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 2
# 	length type 0
# 	number of bits 266
# PARSING 01001000000000111101001100001000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 2
# 	length type 0
# 	number of bits 244
# PARSING 11000010000000000100000110000000000100...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 1
# 	number of subpackets 1
# PARSING 00000110000000000100001010000000000110...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 1
# 	length type 1
# 	number of subpackets 1
# PARSING 00001010000000000110100110000000000101...
#         VVVTTTILLLLLLLLLLL
# 	version 0
# 	ID 2
# 	length type 1
# 	number of subpackets 1
# PARSING 10100110000000000101001000000000100101...
#         VVVTTTILLLLLLLLLLL
# 	version 5
# 	ID 1
# 	length type 1
# 	number of subpackets 1
# PARSING 01001000000000100101101100001000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 2
# 	length type 0
# 	number of bits 150
# PARSING 11000010000000000101001010000000000100...
#         VVVTTTILLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 1
# 	number of subpackets 1
# PARSING 01001010000000000100001000000000010111...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 2
# 	length type 1
# 	number of subpackets 1
# PARSING 00001000000000010111001110100000000001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 0
# 	ID 2
# 	length type 0
# 	number of bits 92
# PARSING 11101000000000010001100100100000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 2
# 	length type 0
# 	number of bits 70
# PARSING 01001000000000001100001110000000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 2
# 	length type 0
# 	number of bits 48
# PARSING 11100000000000000110100011001110010101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 0
# 	number of bits 26
# PARSING 00110011100101011001100110
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 50486
# 	end - 26
# PARSING 11001000000000101111101101001010010101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 6
# 	ID 2
# 	length type 0
# 	number of bits 190
# PARSING 11010010100101011101111011001001001001...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 285620
# 	end - 31
# PARSING 10010011110100111111100110010100100011...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 58358
# 	end - 26
# PARSING 01010010001101111010110011101101001100...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 24458806
# 	end - 41
# PARSING 00010011100111111111111010101111010011...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 55828761265
# 	end - 51
# PARSING 01110011111101111111110110100101111000...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 260006629
# 	end - 41
# PARSING 11000000000000101000000111001001010101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 6
# 	ID 0
# 	length type 0
# 	number of bits 160
# PARSING 01110010010101011000011110110011000110...
#         VVVTTTAAAAA
# 	version 3
# 	ID 4
# 	value - 159158197352
# 	end - 56
# PARSING 10010011011111000110000010011111110011...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 3020
# 	end - 21
# PARSING 00010011111110011111110000110000010011...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 16380036
# 	end - 36
# PARSING 11110011010111000101100110010101101011...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 2763
# 	end - 21
# PARSING 00110010101101011110100001
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 21969
# 	end - 26
# PARSING 01001100000000000101010011001111110011...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 2
# 	ID 3
# 	length type 0
# 	number of bits 21
# PARSING 001100111111001100001
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 3889
# 	end - 21
# PARSING 10100100000000001111011011101000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 1
# 	length type 0
# 	number of bits 61
# PARSING 10111010000000001010010011000000001011...
#         VVVTTTILLLLLLLLLLL
# 	version 5
# 	ID 6
# 	length type 1
# 	number of subpackets 2
# PARSING 10010011000000001011001100000000101100...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 128
# 	end - 16
# PARSING 101100110000000010110001000
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 128
# 	end - 16
# PARSING 10110001000
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 8
# 	end - 11
# PARSING 10100100000000100011000111101000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 5
# 	ID 1
# 	length type 0
# 	number of bits 140
# PARSING 01111010000000001001100010000000001100...
#         VVVTTTILLLLLLLLLLL
# 	version 3
# 	ID 6
# 	length type 1
# 	number of subpackets 2
# PARSING 01100010000000001100010001001101100011...
#         VVVTTTILLLLLLLLLLL
# 	version 3
# 	ID 0
# 	length type 1
# 	number of subpackets 3
# PARSING 00010001001101100011100101000110001100...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 9
# 	end - 11
# PARSING 10110001110010100011000110000000000000...
#         VVVTTTAAAAA
# 	version 5
# 	ID 4
# 	value - 14
# 	end - 11
# PARSING 01010001100011000000000000010000100010...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 12
# 	end - 11
# PARSING 01100000000000001000010001000101100010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 0
# 	length type 0
# 	number of bits 33
# PARSING 000100010110001000100000010001100
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 11
# 	end - 11
# PARSING 0001000100000010001100
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 8
# 	end - 11
# PARSING 00010001100
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 12
# 	end - 11
# PARSING 1111001011000100
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 100
# 	end - 16
# PARSING 00100100000000011111100101011000000000...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 1
# 	ID 1
# 	length type 0
# 	number of bits 126
# PARSING 01010110000000001011110010001110011110...
#         VVVTTTILLLLLLLLLLL
# 	version 2
# 	ID 5
# 	length type 1
# 	number of subpackets 2
# PARSING 11110010001110011110110101100011010111...
#         VVVTTTAAAAA
# 	version 7
# 	ID 4
# 	value - 433395191
# 	end - 46
# PARSING 10010010001110011110110101100011010111...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 433395191
# 	end - 46
# PARSING 0101001111100010
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 242
# 	end - 16
# PARSING 11100000000000000010110101000111101100...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 7
# 	ID 0
# 	length type 0
# 	number of bits 11
# PARSING 01010001111
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 15
# 	end - 11
# PARSING 01100100000000011001001101001101011001...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 100
# PARSING 11010011010110011011001101011101000000...
#         VVVTTTAAAAA
# 	version 6
# 	ID 4
# 	value - 43373
# 	end - 26
# PARSING 01110100000000001101000011000001110010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 5
# 	length type 0
# 	number of bits 52
# PARSING 00110000011100100111101001111101110001...
#         VVVTTTAAAAA
# 	version 1
# 	ID 4
# 	value - 3
# 	end - 11
# PARSING 10010011110100111110111000100011001001...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 238911790
# 	end - 41
# PARSING 01100100000000010101100101001010010101...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 3
# 	ID 1
# 	length type 0
# 	number of bits 86
# PARSING 01010010100101011111001001001110100000...
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 17897
# 	end - 26
# PARSING 00111010000000001000010011001100010101...
#         VVVTTTILLLLLLLLLLL
# 	version 1
# 	ID 6
# 	length type 1
# 	number of subpackets 2
# PARSING 00010011001100010101101010011001100010...
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 2331
# 	end - 21
# PARSING 010100110011000101011
#         VVVTTTAAAAA
# 	version 2
# 	ID 4
# 	value - 2331
# 	end - 21
# PARSING 10001100000000001010101001000010010010...
#         VVVTTTILLLLLLLLLLLLLLL
# 	version 4
# 	ID 3
# 	length type 0
# 	number of bits 42
# PARSING 10010000100100100110001001111100101010...
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 4
# 	end - 11
# PARSING 1001001100010011111001010101001
#         VVVTTTAAAAA
# 	version 4
# 	ID 4
# 	value - 539737
# 	end - 31
# PARSING 000100010010
#         VVVTTTAAAAA
# 	version 0
# 	ID 4
# 	value - 9
# 	end - 11

# %%
print(Packet(inputs).to_string())
# Out:
# ID 0:
# 	ID 1:
# 		value = 60
# 		value = 252
# 		value = 168
# 		value = 61
# 		value = 186
# 	ID 3:
# 		value = 5
# 		value = 237
# 		value = 11
# 	value = 322158
# 	ID 1:
# 		ID 7:
# 			value = 180763931
# 			value = 180763931
# 		value = 225622007682
# 	ID 1:
# 		ID 6:
# 			ID 0:
# 				value = 11
# 				value = 4
# 				value = 15
# 			ID 0:
# 				value = 10
# 				value = 14
# 				value = 2
# 		value = 14
# 	value = 402435806556
# 	ID 1:
# 		ID 7:
# 			ID 0:
# 				value = 12
# 				value = 5
# 				value = 3
# 			ID 0:
# 				value = 15
# 				value = 14
# 				value = 10
# 		value = 239
# 	ID 1:
# 		ID 5:
# 			value = 850169868
# 			value = 54926
# 		value = 132
# 	ID 0:
# 		value = 213
# 		value = 3721
# 		value = 45
# 	ID 0:
# 		value = 34039
# 		value = 140186
# 		value = 8958207
# 		value = 148
# 	ID 1:
# 		ID 5:
# 			value = 10767446
# 			value = 59484
# 		value = 22004
# 	ID 0:
# 		value = 6
# 		value = 9618683
# 	ID 1:
# 		value = 80330
# 		ID 6:
# 			value = 15582291
# 			value = 46
# 	ID 2:
# 		value = 133
# 		value = 205912145
# 		value = 2888
# 		value = 740257
# 	ID 2:
# 		value = 2065890333
# 		value = 995266
# 		value = 7294123
# 	ID 1:
# 		value = 206
# 		value = 23
# 		value = 122
# 	value = 492927
# 	ID 1:
# 		value = 108
# 		value = 22
# 	ID 1:
# 		value = 12
# 		ID 6:
# 			value = 35321
# 			value = 2709935303
# 	value = 150
# 	ID 1:
# 		ID 6:
# 			value = 190
# 			value = 192
# 		value = 34231
# 	ID 1:
# 		value = 238
# 		value = 49
# 		value = 167
# 		value = 15
# 	ID 1:
# 		ID 5:
# 			ID 0:
# 				value = 11
# 				value = 10
# 				value = 9
# 			ID 0:
# 				value = 2
# 				value = 4
# 				value = 9
# 		value = 3111
# 	value = 99591370
# 	ID 2:
# 		value = 10131437
# 		value = 178
# 	ID 1:
# 		value = 17
# 		ID 6:
# 			value = 1715
# 			value = 7
# 	ID 1:
# 		value = 46
# 	ID 1:
# 		value = 226439
# 		ID 5:
# 			value = 1904
# 			value = 12178264
# 	ID 1:
# 		ID 5:
# 			value = 125
# 			value = 125
# 		value = 468803
# 	ID 3:
# 		value = 120794611
# 		value = 526482
# 		value = 14239
# 		value = 2717086384
# 		value = 90928092
# 	value = 1
# 	ID 2:
# 		value = 369981
# 	value = 1024592
# 	ID 1:
# 		value = 49095
# 		ID 7:
# 			value = 5310
# 			value = 248204038
# 	ID 1:
# 		ID 0:
# 			value = 3
# 			value = 15
# 			value = 10
# 		ID 0:
# 			value = 8
# 			value = 6
# 			value = 11
# 		ID 0:
# 			value = 2
# 			value = 11
# 			value = 11
# 	ID 1:
# 		ID 5:
# 			ID 0:
# 				value = 9
# 				value = 5
# 				value = 13
# 			ID 0:
# 				value = 3
# 				value = 7
# 				value = 7
# 		value = 136
# 	value = 10
# 	ID 1:
# 		ID 7:
# 			value = 63186
# 			value = 26100
# 		value = 92
# 	ID 0:
# 		ID 1:
# 			value = 3
# 			value = 5
# 			value = 11
# 		ID 1:
# 			value = 4
# 			value = 14
# 			value = 8
# 		ID 1:
# 			value = 5
# 			value = 8
# 			value = 3
# 	value = 221306755
# 	ID 3:
# 		value = 180936819
# 		value = 13
# 		value = 2
# 		value = 1088
# 	ID 1:
# 		ID 3:
# 			ID 0:
# 				ID 1:
# 					ID 3:
# 						ID 0:
# 							ID 1:
# 								ID 2:
# 									ID 2:
# 										ID 0:
# 											ID 1:
# 												ID 2:
# 													ID 1:
# 														ID 2:
# 															ID 0:
# 																ID 2:
# 																	ID 2:
# 																		ID 2:
# 																			ID 2:
# 																				ID 0:
# 																					value = 50486
# 	ID 2:
# 		value = 285620
# 		value = 58358
# 		value = 24458806
# 		value = 55828761265
# 		value = 260006629
# 	ID 0:
# 		value = 159158197352
# 		value = 3020
# 		value = 16380036
# 		value = 2763
# 		value = 21969
# 	ID 3:
# 		value = 3889
# 	ID 1:
# 		ID 6:
# 			value = 128
# 			value = 128
# 		value = 8
# 	ID 1:
# 		ID 6:
# 			ID 0:
# 				value = 9
# 				value = 14
# 				value = 12
# 			ID 0:
# 				value = 11
# 				value = 8
# 				value = 12
# 		value = 100
# 	ID 1:
# 		ID 5:
# 			value = 433395191
# 			value = 433395191
# 		value = 242
# 	ID 0:
# 		value = 15
# 	ID 1:
# 		value = 43373
# 		ID 5:
# 			value = 3
# 			value = 238911790
# 	ID 1:
# 		value = 17897
# 		ID 6:
# 			value = 2331
# 			value = 2331
# 	ID 3:
# 		value = 4
# 		value = 539737
# 	value = 9

# %%
solve1(inputs)
# Out:
# 906

# %% [markdown]
# ### Test part 2

# %%
tests = [
    "C200B40A82",
    "04005AC33890",
    "880086C3E88112",
    "CE00C43D881120",
    "D8005AC2A8F0",
    "F600BC2D8F",
    "9C005AC2F8F0",
    "9C0141080250320F1802104A08"
]

for t in tests:
    print(solve2(parse_input([t])))
# Out:
# 3
# 54
# 7
# 9
# 1
# 0
# 0
# 1

# %%
solve2(inputs)
# Out:
# 819324480368

# %%
solve2()
